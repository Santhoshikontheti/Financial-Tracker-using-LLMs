# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="phi3")
llm.invoke("The first man on the moon was ...")
# Out:
# 'Neil Armstrong. He became the first person to step onto the lunar surface on July 20, 1969, during NASA\'s Apollo 11 mission. His famous quote upon stepping onto the Moon is, "That\'s one small step for [a] man, one giant leap for mankind."'

# %%
llm.invoke("Can you add an appropriate category next to each of the following expenses.Respond with a list of categories such that Lidl Dig Trading GmbHCo as Groceries,Bäcker Dries sagt Danke as Restaurants,PH Pizza Hut FRANKFURT as Restaurants,TEDi Fil Mainz KFN as Shopping..According to above things do categorize below Ramesh Prasadam Scalable Capital Broker saving, PayPal Europe S.a.r.l. et Cie S.C.A,Bargeldauszahlung Deutsche Bank///DE,'/MISTRAL_SO//ZZ1FWEQ15VWLKMJTH//CHA N//SFA//USTRD//Kartenzahlung ARAL Mainz-Kostheim Hochheimer Stra")
# Out:
# '1. Ramesh Prasadam Scalable Capital Broker saving - Investments/Finance\n2. PayPal Europe S.a.r.l. et Cie S.C.A - Electronic Transactions/Payment Services\n3. Bargeldauszahlung Deutsche Bank///DE - Banking/Money Transfer\n4. Kartenzahlung ARAL Mainz-Kostheim Hochheimer Stra - Retail/Local Payments'

# %%
import pandas as pd
import datetime
import re
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
#Read csv File
df =pd.read_csv("ardata.csv")

# %%
df
# Out:
#            Date                        Name / Description  Amount (EUR)
# 0    2024-01-02                        Income from Salary       1150.00
# 1    2024-01-02             Dinner at Hindukus Restaurant        -40.80
# 2    2024-01-02          Grocery shopping at Desi Grocery        -20.00
# 3    2024-01-02                  Grocery shopping at Lidl         -8.28
# 4    2024-01-02  Grocery shopping at Supermarket Istanbul        -25.34
# ..          ...                                       ...           ...
# 112  2024-05-21                      SUPERMARKET ISTANBUL        -18.10
# 113  2024-05-21                                  DM MOVIE        -21.90
# 114  2024-05-22               Cash Withdrawal. Debit Card       -100.00
# 115  2024-05-22         Cash Deposit SB SB-DEPOSIT HARRAS        870.00
# 116  2024-05-22                         WBS CODING SCHOOL       -588.00
#
# [117 rows x 3 columns]

# %%
#Adding a column Income to know Income and Expenses
df['income/expenses']= np.where(df['Amount (EUR)'] >= 0, 'income', 'expenses')

# %%
df
# Out:
#            Date                        Name / Description  Amount (EUR)  \
# 0    2024-01-02                        Income from Salary       1150.00
# 1    2024-01-02             Dinner at Hindukus Restaurant        -40.80
# 2    2024-01-02          Grocery shopping at Desi Grocery        -20.00
# 3    2024-01-02                  Grocery shopping at Lidl         -8.28
# 4    2024-01-02  Grocery shopping at Supermarket Istanbul        -25.34
# ..          ...                                       ...           ...
# 112  2024-05-21                      SUPERMARKET ISTANBUL        -18.10
# 113  2024-05-21                                  DM MOVIE        -21.90
# 114  2024-05-22               Cash Withdrawal. Debit Card       -100.00
# 115  2024-05-22         Cash Deposit SB SB-DEPOSIT HARRAS        870.00
# 116  2024-05-22                         WBS CODING SCHOOL       -588.00
#
#     income/expenses
# 0            income
# 1          expenses
# 2          expenses
# 3          expenses
# 4          expenses
# ..              ...
# 112        expenses
# 113        expenses
# 114        expenses
# 115          income
# 116        expenses
#
# [117 rows x 4 columns]

# %%
unique_transactions = df["Name / Description"].unique()
len(unique_transactions)
# Out:
# 50

# %%
unique_transactions[0:60]
# Out:
# array(['Income from Salary', 'Dinner at Hindukus Restaurant',
#        'Grocery shopping at Desi Grocery', 'Grocery shopping at Lidl',
#        'Grocery shopping at Supermarket Istanbul', 'Cash Withdrawal',
#        'Personal Care Products Purchase', 'Utility Bill Payment',
#        'Miscellaneous Expense', 'DB payment', 'Fee for Service',
#        'Gym Membership Fee', 'Insurance Premium Payment',
#        'Grocery shopping at Paryan Lebensmittel',
#        'Grocery shopping at Orient Asia Supermarket',
#        'Dinner at Palmen Grill', 'Uncategorised Transaction',
#        'Grocery shopping at Haffez Bazar', 'Dinner at Sara-H Restaurant',
#        'Clothing shopping at Mode Paris', 'Fees for Bank Account',
#        'Income from Cashback', 'Clothing shopping at SHEIN.COM',
#        'Payment at Lidl', 'Payment for Services', 'Statement',
#        'Credit Transfer', 'RSG Group GmbH M--- M- McFIT: Summer',
#        'RESTAURANT NIGIN', 'DB Sales Company Subscription to',
#        'Telefonica Germany GmbH + Co', 'LIDL SAYS THANK YOU',
#        'SUPERMARKET ISTANBUL', 'Cash Withdrawal. Debit Card.',
#        'HAGEBAU MUNICH-NORTH THANKS', 'DM MOVIE', 'Account Balance on',
#        'DM MOVIE.', 'SumUp .Desi Grocery', 'eCommerce-shein.com shopping',
#        'Fee Statement', 'RSG Group GmbH M--- M- McFIT', 'Citizen Bonus',
#        'Takko Fashion', 'Cash Withdrawal. Debit Card. GA',
#        'DB Sales Company Subscription', 'Telefonica Germany GmbH + Co.',
#        'Cash Withdrawal. Debit Card', 'Cash Deposit SB SB-DEPOSIT HARRAS',
#        'WBS CODING SCHOOL'], dtype=object)

# %%
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    yield stop

index_list = list(hop(0, len(unique_transactions), 30))
index_list
# Out:
# [0, 30, 50]

# %%
def categorize_transactions(transaction_names, llm):
    response = llm.invoke("Can you add an appropriate category to the following expenses. For example: Dinner at Hindukus Restaurant - Food, Grocery shopping at Desi Grocery - Grocery,Income from Salary -Income  etc. Grocery shopping at Lidl - Grocery. " + transaction_names)
    response = response.split('\n')

    print(response)

    # Put in dataframe
    categories_df = pd.DataFrame({'Transaction vs category': response})
    categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)

    return categories_df

# %%
categorize_transactions('transaction_names',
                        llm)
# Out:
# ['Grocery Shopping at Lidl - Grocery/Food Expenses', '', 'This category is appropriate because the expense relates directly to purchasing food items and household supplies, which are classified under groceries. Additionally, if the purchased items were used for cooking or consumption, it could also fall under Food Expenses.']
#                              Transaction vs category  \
# 0   Grocery Shopping at Lidl - Grocery/Food Expenses
# 1
# 2  This category is appropriate because the expen...
#
#                                          Transaction               Category
# 0                           Grocery Shopping at Lidl  Grocery/Food Expenses
# 1                                                                      None
# 2  This category is appropriate because the expen...                   None

# %%
# Intialise the categories_df_all dataframe
categories_df_all = pd.DataFrame()

# Loop through the index_list
for i in range(0, len(index_list)-1):
    transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
    transaction_names = ','.join(transaction_names)

    categories_df = categorize_transactions(transaction_names, llm)
    categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# ['1. Dinner at Hindukus Restaurant - Food & Entertainment', '2. Grocery shopping at Desi Grocery - Groceries', '3. Income from Salary - Income', '4. Dinner at Hindukus Restaurant - Food & Entertainment', '5. Grocery shopping at Lidl - Groceries', '6. Cash Withdrawal - Financial Transactions', '7. Personal Care Products Purchase - Household Items', '8. Utility Bill Payment - Bills and Subscriptions', '9. Miscellaneous Expense - Other', '10. DB payment - Business Expenses', '11. Fee for Service - Services', '12. Gym Membership Fee - Health & Wellness', '13. Insurance Premium Payment - Insurance', '14. Grocery shopping at Paryan Lebensmittel - Groceries', '15. Dinner at Palmen Grill - Food & Entertainment', '16. Uncategorised Transaction - Miscellaneous', '17. Grocery shopping at Haffez Bazar - Groceries', '18. Dinner at Sara-H Restaurant - Food & Entertainment', '19. Clothing shopping at Mode Paris - Apparel and Accessories', '20. Fees for Bank Account - Financial Transactions', '21. Income from Cashback - Income', '22. Clothing shopping at SHEIN.COM - Apparel and Accessories', '23. Payment at Lidl - Groceries/Food', '24. Payment for Services - Services', '25. Statement - Financial Transactions', '26. Credit Transfer - Financial Transactions']
# ['1. Grocery shopping at Lidl - **Grocery**', '2. Telefonica Germany GmbH + Co., DM MOVIE subscription - **Entertainment/Subscriptions**', '3. Supermarkt Istanbul, HAGEBAU MUNICH-NORTH THANKS - **Dining & Grocery Shopping** (Grocery if only the shopping part is considered)', '4. DM MOVIE, Account Balance on DM MOVIE - **Entertainment/Subscriptions**', '5. SumUp., eCommerce-shein.com shopping - **Online Purchases**', '6. RSG Group GmbH M--- M- McFIT, Citizen Bonus - **Investments & Subscriptions** (Considering the investment aspect of Citizen Bonus)', '7. Takko Fashion, Cash Withdrawal - **Transactions/Withdrawals**', '8. DB Sales Company Subscription, Telefonica Germany GmbH + Co., Cash Withdrawal - **Subscriptions & Transactions/Withdrawals**', '9. SB-DEPOSIT HARRAS, Cash Deposit - **Deposits**']

# %%
categories_df_all
# Out:
#                               Transaction vs category  \
# 0   1. Dinner at Hindukus Restaurant - Food & Ente...
# 1     2. Grocery shopping at Desi Grocery - Groceries
# 2                      3. Income from Salary - Income
# 3   4. Dinner at Hindukus Restaurant - Food & Ente...
# 4             5. Grocery shopping at Lidl - Groceries
# 5         6. Cash Withdrawal - Financial Transactions
# 6   7. Personal Care Products Purchase - Household...
# 7   8. Utility Bill Payment - Bills and Subscriptions
# 8                    9. Miscellaneous Expense - Other
# 9                  10. DB payment - Business Expenses
# 10                     11. Fee for Service - Services
# 11         12. Gym Membership Fee - Health & Wellness
# 12          13. Insurance Premium Payment - Insurance
# 13  14. Grocery shopping at Paryan Lebensmittel - ...
# 14  15. Dinner at Palmen Grill - Food & Entertainment
# 15      16. Uncategorised Transaction - Miscellaneous
# 16   17. Grocery shopping at Haffez Bazar - Groceries
# 17  18. Dinner at Sara-H Restaurant - Food & Enter...
# 18  19. Clothing shopping at Mode Paris - Apparel ...
# 19  20. Fees for Bank Account - Financial Transact...
# 20                  21. Income from Cashback - Income
# 21  22. Clothing shopping at SHEIN.COM - Apparel a...
# 22               23. Payment at Lidl - Groceries/Food
# 23                24. Payment for Services - Services
# 24             25. Statement - Financial Transactions
# 25       26. Credit Transfer - Financial Transactions
# 26          1. Grocery shopping at Lidl - **Grocery**
# 27  2. Telefonica Germany GmbH + Co., DM MOVIE sub...
# 28  3. Supermarkt Istanbul, HAGEBAU MUNICH-NORTH T...
# 29  4. DM MOVIE, Account Balance on DM MOVIE - **E...
# 30  5. SumUp., eCommerce-shein.com shopping - **On...
# 31  6. RSG Group GmbH M--- M- McFIT, Citizen Bonus...
# 32  7. Takko Fashion, Cash Withdrawal - **Transact...
# 33  8. DB Sales Company Subscription, Telefonica G...
# 34  9. SB-DEPOSIT HARRAS, Cash Deposit - **Deposits**
#
#                                           Transaction  \
# 0                    1. Dinner at Hindukus Restaurant
# 1                 2. Grocery shopping at Desi Grocery
# 2                               3. Income from Salary
# 3                    4. Dinner at Hindukus Restaurant
# 4                         5. Grocery shopping at Lidl
# 5                                  6. Cash Withdrawal
# 6                  7. Personal Care Products Purchase
# 7                             8. Utility Bill Payment
# 8                            9. Miscellaneous Expense
# 9                                      10. DB payment
# 10                                11. Fee for Service
# 11                             12. Gym Membership Fee
# 12                      13. Insurance Premium Payment
# 13        14. Grocery shopping at Paryan Lebensmittel
# 14                         15. Dinner at Palmen Grill
# 15                      16. Uncategorised Transaction
# 16               17. Grocery shopping at Haffez Bazar
# 17                    18. Dinner at Sara-H Restaurant
# 18                19. Clothing shopping at Mode Paris
# 19                          20. Fees for Bank Account
# 20                           21. Income from Cashback
# 21                 22. Clothing shopping at SHEIN.COM
# 22                                23. Payment at Lidl
# 23                           24. Payment for Services
# 24                                      25. Statement
# 25                                26. Credit Transfer
# 26                        1. Grocery shopping at Lidl
# 27  2. Telefonica Germany GmbH + Co., DM MOVIE sub...
# 28  3. Supermarkt Istanbul, HAGEBAU MUNICH-NORTH T...
# 29           4. DM MOVIE, Account Balance on DM MOVIE
# 30            5. SumUp., eCommerce-shein.com shopping
# 31     6. RSG Group GmbH M--- M- McFIT, Citizen Bonus
# 32                  7. Takko Fashion, Cash Withdrawal
# 33  8. DB Sales Company Subscription, Telefonica G...
# 34                 9. SB-DEPOSIT HARRAS, Cash Deposit
#
#                                              Category
# 0                                Food & Entertainment
# 1                                           Groceries
# 2                                              Income
# 3                                Food & Entertainment
# 4                                           Groceries
# 5                              Financial Transactions
# 6                                     Household Items
# 7                             Bills and Subscriptions
# 8                                               Other
# 9                                   Business Expenses
# 10                                           Services
# 11                                  Health & Wellness
# 12                                          Insurance
# 13                                          Groceries
# 14                               Food & Entertainment
# 15                                      Miscellaneous
# 16                                          Groceries
# 17                               Food & Entertainment
# 18                            Apparel and Accessories
# 19                             Financial Transactions
# 20                                             Income
# 21                            Apparel and Accessories
# 22                                     Groceries/Food
# 23                                           Services
# 24                             Financial Transactions
# 25                             Financial Transactions
# 26                                        **Grocery**
# 27                    **Entertainment/Subscriptions**
# 28  **Dining & Grocery Shopping** (Grocery if only...
# 29                    **Entertainment/Subscriptions**
# 30                               **Online Purchases**
# 31  **Investments & Subscriptions** (Considering t...
# 32                       **Transactions/Withdrawals**
# 33       **Subscriptions & Transactions/Withdrawals**
# 34                                       **Deposits**

# %%
 categories_df_all.to_csv("categories_df_all.csv", index=False)

# %%
# Get unique categories in categories_df_all
unique_categories = categories_df_all["Category"].unique()
unique_categories
# Out:
# array(['Food & Entertainment', 'Groceries', 'Income',
#        'Financial Transactions', 'Household Items',
#        'Bills and Subscriptions', 'Other', 'Business Expenses',
#        'Services', 'Health & Wellness', 'Insurance', 'Miscellaneous',
#        'Apparel and Accessories', 'Groceries/Food', '**Grocery**',
#        '**Entertainment/Subscriptions**',
#        '**Dining & Grocery Shopping** (Grocery if only the shopping part is considered)',
#        '**Online Purchases**',
#        '**Investments & Subscriptions** (Considering the investment aspect of Citizen Bonus)',
#        '**Transactions/Withdrawals**',
#        '**Subscriptions & Transactions/Withdrawals**', '**Deposits**'],
#       dtype=object)

# %%
# Drop NA values
categories_df_all = categories_df_all.dropna()
# If category contains "Food", then categorise as "Food and Drinks"
categories_df_all.loc[categories_df_all['Category'].str.contains("Food"), 'Category'] = "Food and Drinks"
# If category contains "Clothing", then categorise as "Clothing"
categories_df_all.loc[categories_df_all['Category'].str.contains("Clothing"), 'Category'] = "Clothing"
# If category contains "Services", then categorise as "Services"
categories_df_all.loc[categories_df_all['Category'].str.contains("Services"), 'Category'] = "Services"
# If category contains "Health" or "Wellness", then categorise as "Health and Wellness"
categories_df_all.loc[categories_df_all['Category'].str.contains("Health|Wellness"), 'Category'] = "Health and Wellness"
# If category contains "Sport", then categorise as "Sport
#  and Fitness"
categories_df_all.loc[categories_df_all['Category'].str.contains("Sport"), 'Category'] = "Sport and Fitness"
# If category contains "Travel", then categorise as "Travel"
categories_df_all.loc[categories_df_all['Category'].str.contains("Travel"), 'Category'] = "Travel"

# %%
categories_df_all['Transaction'] = categories_df_all['Transaction'].str.replace(r'^\d+[\.\₁₂₃₄₅₆₇₈₉]\s+', '',regex = True)
categories_df_all

# %%
# Remove the numbering eg "1. " from Transaction column
categories_df_all['Transaction'] = categories_df_all['Transaction'].str.replace(r'\d+\.\s+', '',regex = True)
categories_df_all
# Out:
#                               Transaction vs category  \
# 0   1. Dinner at Hindukus Restaurant - Food & Ente...
# 1     2. Grocery shopping at Desi Grocery - Groceries
# 2                      3. Income from Salary - Income
# 3   4. Dinner at Hindukus Restaurant - Food & Ente...
# 4             5. Grocery shopping at Lidl - Groceries
# 5         6. Cash Withdrawal - Financial Transactions
# 6   7. Personal Care Products Purchase - Household...
# 7   8. Utility Bill Payment - Bills and Subscriptions
# 8                    9. Miscellaneous Expense - Other
# 9                  10. DB payment - Business Expenses
# 10                     11. Fee for Service - Services
# 11         12. Gym Membership Fee - Health & Wellness
# 12          13. Insurance Premium Payment - Insurance
# 13  14. Grocery shopping at Paryan Lebensmittel - ...
# 14  15. Dinner at Palmen Grill - Food & Entertainment
# 15      16. Uncategorised Transaction - Miscellaneous
# 16   17. Grocery shopping at Haffez Bazar - Groceries
# 17  18. Dinner at Sara-H Restaurant - Food & Enter...
# 18  19. Clothing shopping at Mode Paris - Apparel ...
# 19  20. Fees for Bank Account - Financial Transact...
# 20                  21. Income from Cashback - Income
# 21  22. Clothing shopping at SHEIN.COM - Apparel a...
# 22               23. Payment at Lidl - Groceries/Food
# 23                24. Payment for Services - Services
# 24             25. Statement - Financial Transactions
# 25       26. Credit Transfer - Financial Transactions
# 26          1. Grocery shopping at Lidl - **Grocery**
# 27  2. Telefonica Germany GmbH + Co., DM MOVIE sub...
# 28  3. Supermarkt Istanbul, HAGEBAU MUNICH-NORTH T...
# 29  4. DM MOVIE, Account Balance on DM MOVIE - **E...
# 30  5. SumUp., eCommerce-shein.com shopping - **On...
# 31  6. RSG Group GmbH M--- M- McFIT, Citizen Bonus...
# 32  7. Takko Fashion, Cash Withdrawal - **Transact...
# 33  8. DB Sales Company Subscription, Telefonica G...
# 34  9. SB-DEPOSIT HARRAS, Cash Deposit - **Deposits**
#
#                                           Transaction  \
# 0                       Dinner at Hindukus Restaurant
# 1                    Grocery shopping at Desi Grocery
# 2                                  Income from Salary
# 3                       Dinner at Hindukus Restaurant
# 4                            Grocery shopping at Lidl
# 5                                     Cash Withdrawal
# 6                     Personal Care Products Purchase
# 7                                Utility Bill Payment
# 8                               Miscellaneous Expense
# 9                                          DB payment
# 10                                    Fee for Service
# 11                                 Gym Membership Fee
# 12                          Insurance Premium Payment
# 13            Grocery shopping at Paryan Lebensmittel
# 14                             Dinner at Palmen Grill
# 15                          Uncategorised Transaction
# 16                   Grocery shopping at Haffez Bazar
# 17                        Dinner at Sara-H Restaurant
# 18                    Clothing shopping at Mode Paris
# 19                              Fees for Bank Account
# 20                               Income from Cashback
# 21                     Clothing shopping at SHEIN.COM
# 22                                    Payment at Lidl
# 23                               Payment for Services
# 24                                          Statement
# 25                                    Credit Transfer
# 26                           Grocery shopping at Lidl
# 27  Telefonica Germany GmbH + Co., DM MOVIE subscr...
# 28   Supermarkt Istanbul, HAGEBAU MUNICH-NORTH THANKS
# 29              DM MOVIE, Account Balance on DM MOVIE
# 30               SumUp., eCommerce-shein.com shopping
# 31        RSG Group GmbH M--- M- McFIT, Citizen Bonus
# 32                     Takko Fashion, Cash Withdrawal
# 33  DB Sales Company Subscription, Telefonica Germ...
# 34                    SB-DEPOSIT HARRAS, Cash Deposit
#
#                                              Category
# 0                                     Food and Drinks
# 1                                           Groceries
# 2                                              Income
# 3                                     Food and Drinks
# 4                                           Groceries
# 5                              Financial Transactions
# 6                                     Household Items
# 7                             Bills and Subscriptions
# 8                                               Other
# 9                                   Business Expenses
# 10                                           Services
# 11                                Health and Wellness
# 12                                          Insurance
# 13                                          Groceries
# 14                                    Food and Drinks
# 15                                      Miscellaneous
# 16                                          Groceries
# 17                                    Food and Drinks
# 18                            Apparel and Accessories
# 19                             Financial Transactions
# 20                                             Income
# 21                            Apparel and Accessories
# 22                                    Food and Drinks
# 23                                           Services
# 24                             Financial Transactions
# 25                             Financial Transactions
# 26                                        **Grocery**
# 27                    **Entertainment/Subscriptions**
# 28  **Dining & Grocery Shopping** (Grocery if only...
# 29                    **Entertainment/Subscriptions**
# 30                               **Online Purchases**
# 31  **Investments & Subscriptions** (Considering t...
# 32                       **Transactions/Withdrawals**
# 33       **Subscriptions & Transactions/Withdrawals**
# 34                                       **Deposits**

# %%
# Merge the categories_df_all with the transactions_2022_2023.csv dataframe (df)
df = pd.read_csv("ardata.csv")
df.loc[df['Name / Description'].str.contains("Hindukus"), 'Name / Description'] = "Dinner at Hindukus Restaurant"
df = pd.merge(df, categories_df_all, left_on='Name / Description', right_on ='Transaction',how = 'right')
df.head(80)
# Out:
#           Date                Name / Description  Amount (EUR)  \
# 0   2024-01-02     Dinner at Hindukus Restaurant        -40.80
# 1   2024-01-02  Grocery shopping at Desi Grocery        -20.00
# 2   2024-01-08  Grocery shopping at Desi Grocery         -4.80
# 3   2024-03-04  Grocery shopping at Desi Grocery         -8.60
# 4   2024-03-11  Grocery shopping at Desi Grocery        -11.60
# ..         ...                               ...           ...
# 75  2024-04-02                   Credit Transfer         75.00
# 76  2020-04-30                   Credit Transfer       1150.00
# 77  2024-01-02          Grocery shopping at Lidl         -8.28
# 78  2024-01-05          Grocery shopping at Lidl        -26.37
# 79  2024-01-08          Grocery shopping at Lidl         -7.02
#
#                               Transaction vs category  \
# 0   1. Dinner at Hindukus Restaurant - Food & Ente...
# 1     2. Grocery shopping at Desi Grocery - Groceries
# 2     2. Grocery shopping at Desi Grocery - Groceries
# 3     2. Grocery shopping at Desi Grocery - Groceries
# 4     2. Grocery shopping at Desi Grocery - Groceries
# ..                                                ...
# 75       26. Credit Transfer - Financial Transactions
# 76       26. Credit Transfer - Financial Transactions
# 77          1. Grocery shopping at Lidl - **Grocery**
# 78          1. Grocery shopping at Lidl - **Grocery**
# 79          1. Grocery shopping at Lidl - **Grocery**
#
#                          Transaction                Category
# 0      Dinner at Hindukus Restaurant         Food and Drinks
# 1   Grocery shopping at Desi Grocery               Groceries
# 2   Grocery shopping at Desi Grocery               Groceries
# 3   Grocery shopping at Desi Grocery               Groceries
# 4   Grocery shopping at Desi Grocery               Groceries
# ..                               ...                     ...
# 75                   Credit Transfer  Financial Transactions
# 76                   Credit Transfer  Financial Transactions
# 77          Grocery shopping at Lidl             **Grocery**
# 78          Grocery shopping at Lidl             **Grocery**
# 79          Grocery shopping at Lidl             **Grocery**
#
# [80 rows x 6 columns]

# %%
df.to_csv("ardata_categorized116.csv", index=False)
